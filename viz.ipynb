# %%
import pandas as pd
#from pandas_datareader import data
import matplotlib.pyplot as plt

# %%
 import pandas_datareader as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7da9f55a5922> in <module>
# ----> 1 import pandas_datareader as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

bmw = pd.read_csv("bmw.csv")

bmw
# Out:
#      maker_key          model_key  mileage  engine_power registration_date  \
# 0          BMW                118   140411           100        2012-02-01
# 1          BMW                 M4    13929           317        2016-04-01
# 2          BMW                320   183297           120        2012-04-01
# 3          BMW                420   128035           135        2014-07-01
# 4          BMW                425    97097           160        2014-12-01
# ...        ...                ...      ...           ...               ...
# 4838       BMW    218 Gran Tourer    39743           110        2015-10-01
# 4839       BMW  218 Active Tourer    49832           100        2015-06-01
# 4840       BMW    218 Gran Tourer    19633           110        2015-10-01
# 4841       BMW  218 Active Tourer    27920           110        2016-04-01
# 4842       BMW                525   195840           160        2013-01-01
#
#         fuel paint_color     car_type  feature_1  feature_2  feature_3  \
# 0     diesel       black  convertible       True       True      False
# 1     petrol        grey  convertible       True       True      False
# 2     diesel       white  convertible      False      False      False
# 3     diesel         red  convertible       True       True      False
# 4     diesel      silver  convertible       True       True      False
# ...      ...         ...          ...        ...        ...        ...
# 4838  diesel       black          van      False       True      False
# 4839  diesel        grey          van      False       True      False
# 4840  diesel        grey          van      False       True      False
# 4841  diesel       brown          van       True       True      False
# 4842  diesel        grey          van       True       True      False
#
#       feature_4  feature_5  feature_6  feature_7  feature_8  price     sold_at
# 0         False       True       True       True      False  11300  2018-01-01
# 1         False      False       True       True       True  69700  2018-02-01
# 2         False       True      False       True      False  10200  2018-02-01
# 3         False       True       True       True       True  25100  2018-02-01
# 4         False      False       True       True       True  33400  2018-04-01
# ...         ...        ...        ...        ...        ...    ...         ...
# 4838      False      False      False       True      False  14600  2018-08-01
# 4839      False      False      False       True       True  17500  2018-08-01
# 4840      False      False      False       True       True  17000  2018-09-01
# 4841      False      False      False       True       True  22700  2018-09-01
# 4842      False       True      False       True       True  15500  2018-09-01
#
# [4843 rows x 18 columns]

# %%
bmw

# %%
import pandas as pd

tesla = pd.read_csv("Tesla.csv")

#bmw.plot(y = "engine_power", x = "price")
tesla.plot()

# %%
bmw.plot(y = "mileage", x = "price")

# %%
import pandas as pd

g = pd.read_csv("Google_Stock_Price_Test.csv")

#bmw.plot(y = "engine_power", x = "price")
g.plot(x = "Date")   #(y = "open",kind = "pie", subplot = True)  #(x= "volume", y = "close")

# %%
g
# Out:
#          Date    Open    High     Low   Close     Volume
# 0    1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1    1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2    1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3    1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4    1/9/2017  806.40  809.97  802.83  806.65  1,272,400
# 5   1/10/2017  807.86  809.13  803.51  804.79  1,176,800
# 6   1/11/2017  805.00  808.15  801.37  807.91  1,065,900
# 7   1/12/2017  807.14  807.39  799.17  806.36  1,353,100
# 8   1/13/2017  807.48  811.22  806.69  807.88  1,099,200
# 9   1/17/2017  807.08  807.14  800.37  804.61  1,362,100
# 10  1/18/2017  805.81  806.21  800.99  806.07  1,294,400
# 11  1/19/2017  805.12  809.48  801.80  802.17    919,300
# 12  1/20/2017  806.91  806.91  801.69  805.02  1,670,000
# 13  1/23/2017  807.25  820.87  803.74  819.31  1,963,600
# 14  1/24/2017  822.30  825.90  817.82  823.87  1,474,000
# 15  1/25/2017  829.62  835.77  825.06  835.67  1,494,500
# 16  1/26/2017  837.81  838.00  827.01  832.15  2,973,900
# 17  1/27/2017  834.71  841.95  820.44  823.31  2,965,800
# 18  1/30/2017  814.66  815.84  799.80  802.32  3,246,600
# 19  1/31/2017  796.86  801.25  790.52  796.79  2,160,600

# %%
g.plot(y = 'High', x = 'Date')

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['seaborn-talk',
#  'seaborn-dark',
#  'Solarize_Light2',
#  'seaborn-dark-palette',
#  'seaborn-paper',
#  'bmh',
#  'dark_background',
#  'seaborn',
#  'fivethirtyeight',
#  'seaborn-poster',
#  'seaborn-darkgrid',
#  'seaborn-colorblind',
#  'seaborn-deep',
#  'classic',
#  'seaborn-muted',
#  '_classic_test',
#  'seaborn-notebook',
#  'grayscale',
#  'ggplot',
#  'seaborn-whitegrid',
#  'seaborn-bright',
#  'seaborn-white',
#  'tableau-colorblind10',
#  'fast',
#  'seaborn-pastel',
#  'seaborn-ticks']

# %%
plt.style.use("dark_background")
g.plot(y = 'High', x = 'Date')

# %%
g.High.plot( kind = "line") #x = "Date",

# %%
import pandas as pd
import matplotlib.pyplot as plt


p = pd.read_csv("PotatoPrice.csv")
p
# Out:
#    year  jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0  2018   20   21   22   23   24   24   30   23   22   21   18   22
# 1  2019   18   22   20   20   22   25   23   20   19   20   16   20
# 2  2020   22   21   23   24   25   26   27   28   20   18   20   21

# %%
p.plot( y = "jan", x = "year" )
p.plot( y = "Jun", x = "year" )

# %%
p[["year","jan","Feb"]].plot()

# %%
import pandas as pd

nba = pd.read_csv("nba.csv")
Output = None
nba.head(10)
#Output
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]

# %%
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(10)
#nba["Salary"].rank(ascending = False).astype("int")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College   Salary
# 0                Texas  7730337
# 1            Marquette  6796117
# 2    Boston University        0
# 3        Georgia State  1148640
# 4                  NaN  5000000
# ..                 ...      ...
# 453             Butler  2433333
# 454                NaN   900000
# 455                NaN  2900000
# 456             Kansas   947276
# 457                NaN        0
#
# [458 rows x 9 columns]

# %%
nba["Rank by Salary"] = nba["Salary"].rank(ascending = False).astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-fda325efbf3f> in <module>
# ----> 1 nba["Rank by Salary"] = nba["Salary"].rank(ascending = False).astype("int")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     866
#     867         if not np.isfinite(arr).all():
# --> 868             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     869
#     870     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
nba["Salary"].rank(ascending = False).astype("int")
# Out:
# 0       97
# 1      110
# 2      452
# 3      322
# 4      147
#       ...
# 453    241
# 454    383
# 455    214
# 456    367
# 457    452
# Name: Salary, Length: 458, dtype: int64

# %%
nba["Rank by Salary"] = nba["Salary"].rank(ascending = False).astype("int")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College   Salary   dd  Rank by Salary
# 0                Texas  7730337   97              97
# 1            Marquette  6796117  110             110
# 2    Boston University        0  452             452
# 3        Georgia State  1148640  322             322
# 4                  NaN  5000000  147             147
# ..                 ...      ...  ...             ...
# 453             Butler  2433333  241             241
# 454                NaN   900000  383             383
# 455                NaN  2900000  214             214
# 456             Kansas   947276  367             367
# 457                NaN        0  452             452
#
# [458 rows x 11 columns]

# %%
nba.sort_values(by = "Salary", ascending = False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 269     Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 2       John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight            College    Salary   dd  Rank by Salary
# 109   212.0                NaN  25000000    1               1
# 169   250.0                NaN  22970500    2               2
# 33    240.0           Syracuse  22875000    3               3
# 251   265.0                NaN  22359364    4               4
# 339   235.0       Georgia Tech  22192730    5               5
# ..      ...                ...       ...  ...             ...
# 269   190.0            Detroit         0  452             452
# 409   250.0       Fresno State         0  452             452
# 2     205.0  Boston University         0  452             452
# 264   180.0               UCLA         0  452             452
# 457     NaN                NaN         0  452             452
#
# [458 rows x 11 columns]

# %%
df = pd.read_csv("/home/metaphor/csv/employees.csv")
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["Team"] = df["Team"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    category
# dtypes: category(1), float64(1), int64(1), object(5)
# memory usage: 56.2+ KB

# %%
df["Team"].values
# Out:
# [Marketing, NaN, Finance, Finance, Client Services, ..., Distribution, Finance, Product, Business Development, Sales]
# Length: 1000
# Categories (10, object): [Business Development, Client Services, Distribution, Engineering, ..., Legal, Marketing, Product, Sales]

# %%
mask = df["Team"] == "Finance"

# %%
mask
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
df[mask]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 46       Bruce    Male  11/28/2009        10:47 PM  114796    6.796
# ..         ...     ...         ...             ...     ...      ...
# 907  Elizabeth  Female   7/27/1998        11:12 AM  137144   10.081
# 954        Joe    Male   1/19/1980         4:06 PM  119667    1.148
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                 NaN  Finance
# 14               True  Finance
# 46              False  Finance
# ..                ...      ...
# 907             False  Finance
# 954              True  Finance
# 987              True  Finance
# 992              True  Finance
# 996             False  Finance
#
# [102 rows x 8 columns]

# %%
import pandas as pd
rev = pd.read_csv("/home/metaphor/csv/revenue.csv", index_col = "Date")
rev.head()
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933
# 1/4/16       730          904    885
# 1/5/16       114           71    253

# %%
import pandas as pd
import matplotlib.pyplot as plt

rev.plot()

# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])

df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")

df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-14 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-14 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-14 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-14 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-14 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-14 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-14 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-14 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
m1 = df["Gender"].isnull()

# %%
df[m1]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22 2020-07-14 19:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08 2020-07-14 01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11 2020-07-14 18:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20 2020-07-14 14:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28 2020-07-14 01:08:00   66582   11.308
# ..         ...    ...        ...                 ...     ...      ...
# 961    Antonio    NaN 1989-06-18 2020-07-14 21:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28 2020-07-14 14:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10 2020-07-14 20:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10 2020-07-14 16:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23 2020-07-14 06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# 22                True       Client Services
# 27               False                 Legal
# 31               False               Product
# 41                True  Business Development
# ..                 ...                   ...
# 961              False                 Legal
# 972               True                 Sales
# 985              False                 Legal
# 989              False                 Legal
# 995              False          Distribution
#
# [145 rows x 8 columns]

# %%
df.isnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# 3                False  False
# 4                False  False
# ..                 ...    ...
# 995              False  False
# 996              False  False
# 997              False  False
# 998              False  False
# 999              False  False
#
# [1000 rows x 8 columns]

# %%
df[df.isnull()]
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-14 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-14 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-14 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-14 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-14 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-14 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-14 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-14 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
import pandas as pd

nba = pd.read_csv("nba.csv")

nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]

# %%
nba["College"] == "NaN"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Name: College, Length: 458, dtype: bool

# %%
nba[ nba["Salary"] == "NaN" ]
# Out:
# /home/metaphor/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
x , y = nba.shape

# %%
x
# Out:
# 458

# %%
y
# Out:
# 9

# %%
nba.loc[45 , : ]
# Out:
# Name            Tony Wroten
# Team        New York Knicks
# Number                    5
# Position                 SG
# Age                      23
# Height                  6-6
# Weight                  205
# College          Washington
# Salary               167406
# Name: 45, dtype: object

# %%
nba.iloc[4:5]
nba[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-6fbc47623bb7> in <module>
#       1 nba.iloc[4:5]
# ----> 2 nba[0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
#dfObj.loc[ : , 'Age' ]

import pandas as pd

nba = pd.read_csv("nba.csv")

x , y = nba.shape
l = []
for row in range(0,x-1):
    for col in range(0,y-1):
        if nba.iat[row,col] == 8:
            l.append(row)
            break
   

nba.iloc[l]
# Out:
#                     Name                    Team  Number Position   Age  \
# 4          Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 38           Robin Lopez         New York Knicks     8.0        C  28.0
# 56         Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0
# 61       Bismack Biyombo         Toronto Raptors     8.0        C  23.0
# 95            Jeff Green    Los Angeles Clippers     8.0       SF  29.0
# 146             Rudy Gay        Sacramento Kings     8.0       SF  29.0
# 166  Matthew Dellavedova     Cleveland Cavaliers     8.0       PG  25.0
# 187    Spencer Dinwiddie         Detroit Pistons     8.0       PG  23.0
# 241       Deron Williams        Dallas Mavericks     8.0       PG  31.0
# 243      Michael Beasley         Houston Rockets     8.0       SF  27.0
# 263         Bryce Cotton       Memphis Grizzlies     8.0       PG  23.0
# 278         Luke Babbitt    New Orleans Pelicans     8.0       SF  26.0
# 305          Patty Mills       San Antonio Spurs     8.0       PG  27.0
# 345        Tyler Johnson              Miami Heat     8.0       SG  24.0
# 371         Jarell Eddie      Washington Wizards     8.0       SG  24.0
# 388     Danilo Gallinari          Denver Nuggets     8.0       SF  27.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 453         Shelvin Mack               Utah Jazz     8.0       PG  26.0
#
#     Height  Weight        College      Salary
# 4     6-10   231.0            NaN   5000000.0
# 38     7-0   255.0       Stanford  12650000.0
# 56    6-11   275.0           Duke   4582680.0
# 61     6-9   245.0            NaN   2814000.0
# 95     6-9   235.0     Georgetown   9650000.0
# 146    6-8   230.0    Connecticut  12403101.0
# 166    6-4   198.0   Saint Mary's   1147276.0
# 187    6-6   200.0       Colorado    845059.0
# 241    6-3   200.0       Illinois   5378974.0
# 243   6-10   235.0   Kansas State    306527.0
# 263    6-1   165.0     Providence    700902.0
# 278    6-9   225.0         Nevada   1100602.0
# 305    6-0   185.0   Saint Mary's   3578947.0
# 345    6-4   186.0   Fresno State    845059.0
# 371    6-7   218.0  Virginia Tech    561716.0
# 388   6-10   225.0            NaN  14000000.0
# 402    6-5   189.0           UCLA   2148360.0
# 428    6-9   215.0    Wake Forest   8042895.0
# 453    6-3   203.0         Butler   2433333.0

# %%
import pandas as pd

nba = pd.read_csv("nba.csv")

x , y = nba.shape
l = []
for row in range(0,x-1):
    for col in range(0,y-1):
        if nba.iat[row,col] == 8:
            l.append(row)
            break
   

nba.iloc[l]
# Out:
#                     Name                    Team  Number Position   Age  \
# 4          Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 38           Robin Lopez         New York Knicks     8.0        C  28.0
# 56         Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0
# 61       Bismack Biyombo         Toronto Raptors     8.0        C  23.0
# 95            Jeff Green    Los Angeles Clippers     8.0       SF  29.0
# 146             Rudy Gay        Sacramento Kings     8.0       SF  29.0
# 166  Matthew Dellavedova     Cleveland Cavaliers     8.0       PG  25.0
# 187    Spencer Dinwiddie         Detroit Pistons     8.0       PG  23.0
# 241       Deron Williams        Dallas Mavericks     8.0       PG  31.0
# 243      Michael Beasley         Houston Rockets     8.0       SF  27.0
# 263         Bryce Cotton       Memphis Grizzlies     8.0       PG  23.0
# 278         Luke Babbitt    New Orleans Pelicans     8.0       SF  26.0
# 305          Patty Mills       San Antonio Spurs     8.0       PG  27.0
# 345        Tyler Johnson              Miami Heat     8.0       SG  24.0
# 371         Jarell Eddie      Washington Wizards     8.0       SG  24.0
# 388     Danilo Gallinari          Denver Nuggets     8.0       SF  27.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 453         Shelvin Mack               Utah Jazz     8.0       PG  26.0
#
#     Height  Weight        College      Salary
# 4     6-10   231.0            NaN   5000000.0
# 38     7-0   255.0       Stanford  12650000.0
# 56    6-11   275.0           Duke   4582680.0
# 61     6-9   245.0            NaN   2814000.0
# 95     6-9   235.0     Georgetown   9650000.0
# 146    6-8   230.0    Connecticut  12403101.0
# 166    6-4   198.0   Saint Mary's   1147276.0
# 187    6-6   200.0       Colorado    845059.0
# 241    6-3   200.0       Illinois   5378974.0
# 243   6-10   235.0   Kansas State    306527.0
# 263    6-1   165.0     Providence    700902.0
# 278    6-9   225.0         Nevada   1100602.0
# 305    6-0   185.0   Saint Mary's   3578947.0
# 345    6-4   186.0   Fresno State    845059.0
# 371    6-7   218.0  Virginia Tech    561716.0
# 388   6-10   225.0            NaN  14000000.0
# 402    6-5   189.0           UCLA   2148360.0
# 428    6-9   215.0    Wake Forest   8042895.0
# 453    6-3   203.0         Butler   2433333.0

# %%
import pandas as pd

nba = pd.read_csv("nba.csv")

x , y = nba.shape
l = []
for row in range(x):
    if nba.iloc[row].count() != y:
            l.append(row)
            
   

nba.iloc[l]
# Out:
#                  Name            Team  Number Position   Age Height  Weight  \
# 2        John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4       Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 15   Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# 20     Sergey Karasev   Brooklyn Nets    10.0       SG  22.0    6-7   208.0
# ..                ...             ...     ...      ...   ...    ...     ...
# 447       Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
# 450        Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 454         Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455      Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457               NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# 2    Boston University         NaN
# 4                  NaN   5000000.0
# 5                  NaN  12000000.0
# 15                 NaN   3425510.0
# 20                 NaN   1599840.0
# ..                 ...         ...
# 447                NaN   1175880.0
# 450                NaN   2050000.0
# 454                NaN    900000.0
# 455                NaN   2900000.0
# 457                NaN         NaN
#
# [94 rows x 9 columns]

# %%
nba.iloc[4].count()
# Out:
# 8

# %% [markdown]
# # CREATING A DATAFRAME

# %%
import pandas as pd
df = pd.DataFrame([[30, 20, 'Hello'], [None, 50, 'Hi'], [10, 30, 'OK']],
                   columns=['A', 'B', 'C'])
df
# Out:
#       A   B      C
# 0  30.0  20  Hello
# 1   NaN  50     Hi
# 2  10.0  30     OK

# %%
df.at[2,'B']
# Out:
# 30

# %%
df.at[2,'B'] = 16
df
# Out:
#       A   B      C
# 0  30.0  20  Hello
# 1  45.0  50     Hi
# 2  10.0  16     OK

# %%
df.at[2,'B'] = None
df
# Out:
#       A     B      C
# 0  30.0  20.0  Hello
# 1  45.0  50.0     Hi
# 2  10.0   NaN     as

# %%
df.at[1,'A']= 45
df
# Out:
#       A     B      C
# 0  30.0  20.0  Hello
# 1  45.0  50.0     Hi
# 2  10.0   NaN     as

# %%
df.at[1,'A']= "Why"  # No string is allowed in int valued column
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-1dfeeb69fa96> in <module>
# ----> 1 df.at[1,'A']= "Why"  # No string is allowed in int valued column
#       2 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2191         key = list(self._convert_key(key, is_setter=True))
#    2192         key.append(value)
# -> 2193         self.obj._set_value(*key, takeable=self._takeable)
#    2194
#    2195
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3031             series = self._get_item_cache(col)
#    3032             engine = self.index._engine
# -> 3033             engine.set_value(series._values, index, value)
#    3034             return self
#    3035         except (KeyError, TypeError):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# ValueError: could not convert string to float: 'Why'

# %%
df['A'] = "Changed" # But whole column value can be changed as string
df
# Out:
#          A     B      C
# 0  Changed  20.0  Hello
# 1  Changed  50.0     Hi
# 2  Changed   NaN     as

# %%
df['New'] = "New Values" # But whole column value can be changed as string
df
# Out:
#          A     B      C   (2, A)         New
# 0  Changed  20.0  Hello  New Col  New Values
# 1  Changed  50.0     Hi  New Col  New Values
# 2  Changed   NaN     as  New Col  New Values

# %% [markdown]
# # Dataframe cell value by Integer position
#
# ## From the above dataframe, Let’s access the cell value of 1,2 i.e Index 1 and Column 2 i.e Col C

# %%
df.iat[1, 2] #iat - Access a single value for a row/column pair by integer position. Use iat if you only need to get or set a single value in a DataFrame or Series.
# Out:
# 'Hi'

# %% [markdown]
# ## Let’s setup the cell value with the integer position, So we will update the same cell value with NaN i.e. cell(1,0)

# %%
import pandas as pd
df = pd.DataFrame([[30, 20, 'Hello'], [None, 50, 'Hi'], [10, 30, 'OK']],
                   columns=['A', 'B', 'C'])
df
# Out:
#       A   B      C
# 0  30.0  20  Hello
# 1   NaN  50     Hi
# 2  10.0  30     OK

# %%
df.iat[1, 0] = 100
df
# Out:
#        A   B      C
# 0   30.0  20  Hello
# 1  100.0  50     Hi
# 2   10.0  30     OK

# %%
df.iat[1, 1] = "Try" # No string is allowed in int valued column
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-3a0a899e84ef> in <module>
# ----> 1 df.iat[1, 1] = "Try" # No string is allowed in int valued column
#       2 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2191         key = list(self._convert_key(key, is_setter=True))
#    2192         key.append(value)
# -> 2193         self.obj._set_value(*key, takeable=self._takeable)
#    2194
#    2195
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3027             if takeable is True:
#    3028                 series = self._iget_item_cache(col)
# -> 3029                 return series._set_value(index, value, takeable=True)
#    3030
#    3031             series = self._get_item_cache(col)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _set_value(self, label, value, takeable)
#    1135         try:
#    1136             if takeable:
# -> 1137                 self._values[label] = value
#    1138             else:
#    1139                 self.index._engine.set_value(self._values, label, value)
#
# ValueError: invalid literal for int() with base 10: 'Try'

# %% [markdown]
# # Create Excercise From Tutorial

# %%
# Out:
# 'Hi'

# %%
import pandas as pd
def main():
    
    students = [ ('jack', 34, 'Sydeny') ,
                 ('Riti', 30, 'Delhi' ) ,
                 ('Aadi', 16, 'New York') ]
    
    # Create a DataFrame object
    dfObj = pd.DataFrame(students, columns = ['Name' , 'Age', 'City'], index=['a', 'b', 'c']) 
    
    print("Original DataFrame : ", dfObj, sep="\n")
    
    print("***** Select Columns in DataFrame by [] *********")
  
    '''
    Select a Column by Name using []
    '''
    column2 = dfObj['Age']
    
    print("Select column By Name using [] " , column2 , sep='\n')
    print("Type : " , type(column2))
    '''
    Select  Multiple Column by Name using []
    '''
    column2 = dfObj[ ['Age', 'Name'] ]
    
    print("Select multiple columns By Name using [] " , column2 , sep='\n')
    print("Type : " , type(column2))
       
    
    print("**** Selecting by Column Names & Rows Index Labels Using df.loc ******")
    
    '''
    Selecting a Single Column by Column Names
    '''
    columnsData = dfObj.loc[ : , 'Age' ]
    
    print("Select a column By Name using loc " , columnsData , sep='\n')
    print("Type : " , type(columnsData))
    
    '''
    Selecting multiple Columns by Column Names
    '''
    
    # Select only 2 columns from dataFrame and create a new subset DataFrame
    columnsData = dfObj.loc[ : , ['Age', 'Name'] ]
    
    print("Select multiple columns By Name using loc " , columnsData , sep='\n')
    print("Type : " , type(columnsData))
    
    '''
    Selecting a Single Row by Index label
    '''
    
    rowData = dfObj.loc[ 'b' , : ]
    
    print("Select a Single Row " , rowData , sep='\n')
    print("Type : " , type(rowData))
    
    '''
    Selecting multiple Rows by Index labels
    '''
    rowData = dfObj.loc[ ['c' , 'b'] , : ]
    
    print("Select multiple Rows" , rowData , sep='\n')
    
    '''
    Select both Rows & Columns by Index labels
    '''
    
    subset = dfObj.loc[ ['c' , 'b'] ,['Age', 'Name'] ]
    
    print("Select both columns & Rows" , subset , sep='\n')
    
    subset = dfObj.loc[ 'a' : 'c' ,'Age' : 'City' ]
    
    print("Select both columns & Rows with selection range " , subset , sep='\n')
    
    
    print("**** Selecting by Column Indexes & Rows Index Positions Using df.iloc ******")
    
    '''
    Select a single column by Index Position
    '''
    print(" Select column at index 2 ")
    print( dfObj.iloc[ : , 2 ] )
    
    '''
    Select multiple columns by Index range 
    '''
    print(" Select columns in column index range 0 to 2")
    print(dfObj.iloc[:, 0:2])
    
    '''
    Select multiple columns by Indexes in a list 
    '''
    print(" Select columns at column index  0 and 2")
    print(dfObj.iloc[: , [0, 2]])
    
    
    '''
    Select single row by Index Position
    '''
    print(" Select row at index 2 ")
    print( dfObj.iloc[ 1 , :  ] )
    
    '''
    Select multiple rows by Index range 
    '''
    print(" Select rows in row index range 0 to 2")
    print(dfObj.iloc[ 0:2 , : ])
    
    '''
    Select multiple rows by Index positions in a list 
    '''
    print(" Select rows at row index  0 and 2")
    print(dfObj.iloc[[2 ,0 ] , : ])
    
    
    '''
    Select multiple rows & columns by  Index positions
    '''
    print(" Select rows at index 0 & 2 . Also columns at row  1 and 2")
    print(dfObj.iloc[[0 , 2] , [1 , 2] ])
    '''
    Select multiple rows & columns by  Indexes in a range
    '''
    print(" Select rows at index 0 to 2 (2nd index not included) . Also columns at row  0 to 2 (2nd index not included)")
    print(dfObj.iloc[ 0 : 2 ,  1 : 2 ])
 
       
if __name__ == '__main__':
    main()
# Out:
# Original DataFrame :
#    Name  Age      City
# a  jack   34    Sydeny
# b  Riti   30     Delhi
# c  Aadi   16  New York
# ***** Select Columns in DataFrame by [] *********
# Select column By Name using []
# a    34
# b    30
# c    16
# Name: Age, dtype: int64
# Type :  <class 'pandas.core.series.Series'>
# Select multiple columns By Name using []
#    Age  Name
# a   34  jack
# b   30  Riti
# c   16  Aadi
# Type :  <class 'pandas.core.frame.DataFrame'>
# **** Selecting by Column Names & Rows Index Labels Using df.loc ******
# Select a column By Name using loc
# a    34
# b    30
# c    16
# Name: Age, dtype: int64
# Type :  <class 'pandas.core.series.Series'>
# Select multiple columns By Name using loc
#    Age  Name
# a   34  jack
# b   30  Riti
# c   16  Aadi
# Type :  <class 'pandas.core.frame.DataFrame'>
# Select a Single Row
# Name     Riti
# Age        30
# City    Delhi
# Name: b, dtype: object
# Type :  <class 'pandas.core.series.Series'>
# Select multiple Rows
#    Name  Age      City
# c  Aadi   16  New York
# b  Riti   30     Delhi
# Select both columns & Rows
#    Age  Name
# c   16  Aadi
# b   30  Riti
# Select both columns & Rows with selection range
#    Age      City
# a   34    Sydeny
# b   30     Delhi
# c   16  New York
# **** Selecting by Column Indexes & Rows Index Positions Using df.iloc ******
#  Select column at index 2
# a      Sydeny
# b       Delhi
# c    New York
# Name: City, dtype: object
#  Select columns in column index range 0 to 2
#    Name  Age
# a  jack   34
# b  Riti   30
# c  Aadi   16
#  Select columns at column index  0 and 2
#    Name      City
# a  jack    Sydeny
# b  Riti     Delhi
# c  Aadi  New York
#  Select row at index 2
# Name     Riti
# Age        30
# City    Delhi
# Name: b, dtype: object
#  Select rows in row index range 0 to 2
#    Name  Age    City
# a  jack   34  Sydeny
# b  Riti   30   Delhi
#  Select rows at row index  0 and 2
#    Name  Age      City
# c  Aadi   16  New York
# a  jack   34    Sydeny
#  Select rows at index 0 & 2 . Also columns at row  1 and 2
#    Age      City
# a   34    Sydeny
# c   16  New York
#  Select rows at index 0 to 2 (2nd index not included) . Also columns at row  0 to 2 (2nd index not included)
#    Age
# a   34
# b   30

# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])

df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")

df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-14 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-14 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-14 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-14 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-14 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-14 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-14 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-14 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
m1 = df["Team"].isnull()

# %%
m2 = df["Gender"].isnull()

# %%
df[m1 & m2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 91       James    NaN 2005-01-26 2020-07-14 23:00:00  128771    8.309
# 669     Joseph    NaN 1982-03-28 2020-07-14 13:05:00   86564   11.879
# 826        NaN    NaN 1988-08-01 2020-07-14 01:35:00   87103    5.665
# 855    Phillip    NaN 2003-10-20 2020-07-14 11:09:00   89700    2.277
#
#      Senior Management Team
# 91               False  NaN
# 669               True  NaN
# 826               True  NaN
# 855               True  NaN

# %%
df[m1 | m2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-07-14 06:53:00   61933    4.170
# 10      Louise  Female 1980-08-12 2020-07-14 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2020-07-14 19:18:00   64714    4.934
# 22      Joshua     NaN 2012-03-08 2020-07-14 01:58:00   90816   18.816
# 23         NaN    Male 2012-06-14 2020-07-14 16:19:00  125792    5.042
# ..         ...     ...        ...                 ...     ...      ...
# 961    Antonio     NaN 1989-06-18 2020-07-14 21:37:00  103050    3.050
# 972     Victor     NaN 2006-07-28 2020-07-14 14:49:00   76381   11.159
# 985    Stephen     NaN 1983-07-10 2020-07-14 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2020-07-14 16:58:00   38344    3.794
# 995      Henry     NaN 2014-11-23 2020-07-14 06:09:00  132483   16.655
#
#      Senior Management             Team
# 1                 True              NaN
# 10                True              NaN
# 20                True            Legal
# 22                True  Client Services
# 23                True              NaN
# ..                 ...              ...
# 961              False            Legal
# 972               True            Sales
# 985              False            Legal
# 989              False            Legal
# 995              False     Distribution
#
# [184 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
m3 = df["First Name"].notnull()

# %%
df[m3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-14 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-14 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-14 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-14 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-14 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-14 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-14 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-14 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [933 rows x 8 columns]

# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])

df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")

df.sort_values("First Name",inplace = True)
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-07-14 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-07-14 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-14 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-07-14 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-07-14 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-07-14 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-07-14 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-07-14 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-07-14 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-07-14 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [1000 rows x 8 columns]

# %%
m = df["First Name"].duplicated(keep = False)

# %%
mr = ~df["First Name"].duplicated(keep = False)

# %%
df[mr]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-07-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-07-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-07-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-07-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-07-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-07-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-07-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-07-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-07-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %%
mn = ~m

# %%
df[mn]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-07-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-07-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-07-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-07-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-07-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-07-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-07-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-07-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-07-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services
